# %% [markdown]
# ```markdown
# # Required Libraries & Installation
#
# Before running the scripts, install the necessary dependencies:
#
# ```sh
# pip install openslide-python pillow opencv-python numpy
# ```
#
# ### **Libraries Used**
# - `openslide` → Reads whole-slide images (NDPI files)
# - `PIL (Pillow)` → Handles image processing
# - `cv2 (OpenCV)` → Resizes and stitches images
# - `numpy` → Manages image arrays efficiently
#
# Ensure OpenSlide is installed on your system for `.ndpi` file support. 🚀
# ```

# %% [markdown]
# ---

# %% [markdown]
# ### **NDPI to JPEG Tile Converter**
#
# This script processes **NDPI whole-slide images** from histopathology scans, extracting **high-resolution image tiles** for machine learning and analysis.
#
# #### **Key Features**
# ✅ **Processes NDPI files**: Reads large **histopathology whole-slide images** using OpenSlide.
# ✅ **Extracts tiles efficiently**: Converts the images into **1400x1400 px JPEG tiles** to balance quality and storage.
# ✅ **Multi-Level Support**: Extracts tiles from **Level 1** to reduce file size while maintaining detail.
# ✅ **Storage Optimization**: Saves **tiles as JPEG (90% quality)** to optimize space.
#
# This is useful for **deep learning applications**, particularly in medical imaging research like **glioblastoma survival prediction**. 🚀

# %%
import os
import glob
import openslide
from PIL import Image

# Define input and output directories
input_dir = r"D:\MLPR DATASET\PKG - UPENN-GBM_v2\data"
output_root = r"D:\MLPR DATASET\converted_tiles"

# Create output root folder if it doesn't exist
os.makedirs(output_root, exist_ok=True)

# Define tile parameters
tile_size = 1400  # Adjusted for ~3MB per tile
level = 1  # Use Level 1 to reduce file size
jpeg_quality = 90  # Save as JPEG to reduce storage usage

# Get list of all NDPI files in the input directory
ndpi_files = glob.glob(os.path.join(input_dir, "*.ndpi"))
print(f"Found {len(ndpi_files)} NDPI file(s) to process.")

# Process each NDPI file
for ndpi_file in ndpi_files:
    try:
        # Extract base name and create output folder
        base_name = os.path.splitext(os.path.basename(ndpi_file))[0]
        output_folder = os.path.join(output_root, base_name)
        os.makedirs(output_folder, exist_ok=True)
        
        print(f"\nProcessing: {ndpi_file}")
        slide = openslide.OpenSlide(ndpi_file)
    except Exception as e:
        print(f"Error opening {ndpi_file}: {e}")
        continue

    # Get dimensions at the selected resolution level
    width, height = slide.level_dimensions[level]
    print(f"Slide dimensions (Level {level}): {width} x {height}")
    
    tile_count = 0
    # Loop over slide to extract tiles
    for y in range(0, height, tile_size):
        for x in range(0, width, tile_size):
            try:
                tile = slide.read_region((x * 2, y * 2), level, (tile_size, tile_size))  # Adjust for level scaling
                tile = tile.convert("RGB")  # Convert to RGB
                tile_filename = os.path.join(output_folder, f"tile_{x}_{y}.jpg")
                tile.save(tile_filename, "JPEG", quality=jpeg_quality)
                tile_count += 1
            except Exception as e:
                print(f"Error processing tile ({x},{y}) in {ndpi_file}: {e}")
    
    print(f"Finished processing {ndpi_file}. Total tiles created: {tile_count}")
# Out:
# Found 71 NDPI file(s) to process.
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-109.ndpi
# Slide dimensions (Level 1): 72960 x 54144
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-109.ndpi. Total tiles created: 2067
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1108.ndpi
# Slide dimensions (Level 1): 55680 x 38016
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1108.ndpi. Total tiles created: 1120
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1110.ndpi
# Slide dimensions (Level 1): 57600 x 41472
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1110.ndpi. Total tiles created: 1260
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1135.ndpi
# Slide dimensions (Level 1): 61440 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1135.ndpi. Total tiles created: 1584
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1206.ndpi
# Slide dimensions (Level 1): 48000 x 44928
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1206.ndpi. Total tiles created: 1155
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1220.ndpi
# Slide dimensions (Level 1): 55680 x 48384
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1220.ndpi. Total tiles created: 1400
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1273.ndpi
# Slide dimensions (Level 1): 59520 x 40320
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1273.ndpi. Total tiles created: 1247
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1282.ndpi
# Slide dimensions (Level 1): 34560 x 34560
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1282.ndpi. Total tiles created: 625
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1302.ndpi
# Slide dimensions (Level 1): 63360 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1302.ndpi. Total tiles created: 1656
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1352.ndpi
# Slide dimensions (Level 1): 46080 x 44928
# Error processing tile (40600,14000) in D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1352.ndpi:
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1352.ndpi. Total tiles created: 1088
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1405.ndpi
# Slide dimensions (Level 1): 36480 x 39168
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1405.ndpi. Total tiles created: 756
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1534.ndpi
# Slide dimensions (Level 1): 80640 x 50688
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1534.ndpi. Total tiles created: 2146
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1581.ndpi
# Slide dimensions (Level 1): 53760 x 31104
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1581.ndpi. Total tiles created: 897
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-160.ndpi
# Slide dimensions (Level 1): 74880 x 39168
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-160.ndpi. Total tiles created: 1512
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1614.ndpi
# Slide dimensions (Level 1): 69120 x 54144
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1614.ndpi. Total tiles created: 1950
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1640.ndpi
# Slide dimensions (Level 1): 48000 x 41472
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1640.ndpi. Total tiles created: 1050
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1766.ndpi
# Slide dimensions (Level 1): 63360 x 50688
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1766.ndpi. Total tiles created: 1702
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-181.ndpi
# Slide dimensions (Level 1): 46080 x 41472
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-181.ndpi. Total tiles created: 990
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1843.ndpi
# Slide dimensions (Level 1): 57600 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1843.ndpi. Total tiles created: 1512
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1848.ndpi
# Slide dimensions (Level 1): 57600 x 48384
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1848.ndpi. Total tiles created: 1470
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1883.ndpi
# Slide dimensions (Level 1): 32640 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-1883.ndpi. Total tiles created: 864
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-19.ndpi
# Slide dimensions (Level 1): 46080 x 47232
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-19.ndpi. Total tiles created: 1122
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2058.ndpi
# Slide dimensions (Level 1): 48000 x 43776
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2058.ndpi. Total tiles created: 1120
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2100.ndpi
# Slide dimensions (Level 1): 69120 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2100.ndpi. Total tiles created: 1800
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2110.ndpi
# Slide dimensions (Level 1): 53760 x 46080
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2110.ndpi. Total tiles created: 1287
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-213.ndpi
# Slide dimensions (Level 1): 69120 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-213.ndpi. Total tiles created: 1800
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2165.ndpi
# Slide dimensions (Level 1): 69120 x 48384
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2165.ndpi. Total tiles created: 1750
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-219.ndpi
# Slide dimensions (Level 1): 38400 x 40320
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-219.ndpi. Total tiles created: 812
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2310.ndpi
# Slide dimensions (Level 1): 72960 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2310.ndpi. Total tiles created: 1908
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2333.ndpi
# Slide dimensions (Level 1): 65280 x 44928
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2333.ndpi. Total tiles created: 1551
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-243.ndpi
# Slide dimensions (Level 1): 55680 x 35712
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-243.ndpi. Total tiles created: 1040
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2527.ndpi
# Slide dimensions (Level 1): 40320 x 52992
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2527.ndpi. Total tiles created: 1102
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2726.ndpi
# Slide dimensions (Level 1): 65280 x 43776
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2726.ndpi. Total tiles created: 1504
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2837.ndpi
# Slide dimensions (Level 1): 63360 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2837.ndpi. Total tiles created: 1656
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2843.ndpi
# Slide dimensions (Level 1): 32640 x 23040
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2843.ndpi. Total tiles created: 408
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-287.ndpi
# Slide dimensions (Level 1): 61440 x 48384
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-287.ndpi. Total tiles created: 1540
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2923.ndpi
# Slide dimensions (Level 1): 55680 x 47232
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-2923.ndpi. Total tiles created: 1360
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-293.ndpi
# Slide dimensions (Level 1): 36480 x 41472
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-293.ndpi. Total tiles created: 810
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-302.ndpi
# Slide dimensions (Level 1): 44160 x 35712
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-302.ndpi. Total tiles created: 832
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3213.ndpi
# Slide dimensions (Level 1): 30720 x 47232
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3213.ndpi. Total tiles created: 748
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3301.ndpi
# Slide dimensions (Level 1): 51840 x 48384
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3301.ndpi. Total tiles created: 1330
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-334.ndpi
# Slide dimensions (Level 1): 23040 x 20736
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-334.ndpi. Total tiles created: 255
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-349.ndpi
# Slide dimensions (Level 1): 61440 x 34560
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-349.ndpi. Total tiles created: 1100
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-35.ndpi
# Slide dimensions (Level 1): 51840 x 24192
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-35.ndpi. Total tiles created: 684
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-361.ndpi
# Slide dimensions (Level 1): 46080 x 48384
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-361.ndpi. Total tiles created: 1155
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3639.ndpi
# Slide dimensions (Level 1): 46080 x 47232
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3639.ndpi. Total tiles created: 1122
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3741.ndpi
# Slide dimensions (Level 1): 67200 x 49536
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-3741.ndpi. Total tiles created: 1728
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-386.ndpi
# Slide dimensions (Level 1): 51840 x 43776
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-386.ndpi. Total tiles created: 1216
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-393.ndpi
# Slide dimensions (Level 1): 74880 x 54144
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-393.ndpi. Total tiles created: 2106
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-421.ndpi
# Slide dimensions (Level 1): 49920 x 35712
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-421.ndpi. Total tiles created: 936
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-426.ndpi
# Slide dimensions (Level 1): 55680 x 26496
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-426.ndpi. Total tiles created: 760
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-435.ndpi
# Slide dimensions (Level 1): 42240 x 35712
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-435.ndpi. Total tiles created: 806
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-483.ndpi
# Slide dimensions (Level 1): 30720 x 27648
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-483.ndpi. Total tiles created: 440
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-485.ndpi
# Slide dimensions (Level 1): 57600 x 42624
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-485.ndpi. Total tiles created: 1302
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-498.ndpi
# Slide dimensions (Level 1): 63360 x 42624
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-498.ndpi. Total tiles created: 1426
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-504.ndpi
# Slide dimensions (Level 1): 76800 x 54144
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-504.ndpi. Total tiles created: 2145
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-534.ndpi
# Slide dimensions (Level 1): 42240 x 48384
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-534.ndpi. Total tiles created: 1085
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-547.ndpi
# Slide dimensions (Level 1): 57600 x 43776
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-547.ndpi. Total tiles created: 1344
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-553.ndpi
# Slide dimensions (Level 1): 57600 x 51840
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-553.ndpi. Total tiles created: 1596
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-574.ndpi
# Slide dimensions (Level 1): 57600 x 23040
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-574.ndpi. Total tiles created: 714
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-587.ndpi
# Slide dimensions (Level 1): 61440 x 51840
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-587.ndpi. Total tiles created: 1672
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-603.ndpi
# Slide dimensions (Level 1): 34560 x 40320
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-603.ndpi. Total tiles created: 725
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-613.ndpi
# Slide dimensions (Level 1): 59520 x 47232
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-613.ndpi. Total tiles created: 1462
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-662.ndpi
# Slide dimensions (Level 1): 65280 x 46080
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-662.ndpi. Total tiles created: 1551
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-743.ndpi
# Slide dimensions (Level 1): 84480 x 21888
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-743.ndpi. Total tiles created: 976
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-8.ndpi
# Slide dimensions (Level 1): 72960 x 51840
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-8.ndpi. Total tiles created: 2014
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-895.ndpi
# Slide dimensions (Level 1): 61440 x 34560
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-895.ndpi. Total tiles created: 1100
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-961.ndpi
# Slide dimensions (Level 1): 84480 x 50688
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-961.ndpi. Total tiles created: 2257
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-979.ndpi
# Slide dimensions (Level 1): 44160 x 39168
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-979.ndpi. Total tiles created: 896
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-984.ndpi
# Slide dimensions (Level 1): 63360 x 40320
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-984.ndpi. Total tiles created: 1334
#
# Processing: D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-99.ndpi
# Slide dimensions (Level 1): 26880 x 35712
# Finished processing D:\MLPR DATASET\PKG - UPENN-GBM_v2\data\7316UP-99.ndpi. Total tiles created: 520

# %% [markdown]
# ### **Tile Stitching & Compression Script**
#
# This script reconstructs **whole-slide histopathology images** from previously extracted **image tiles** while reducing file size for efficient storage and visualization.
#
# #### **Key Features**
# ✅ **Stitches Tiles Back**: Reads **JPEG tiles** and reconstructs the **original image layout** using tile coordinates.
# ✅ **Downscaling for Compression**: Reduces resolution by a **factor of 10** to save space and improve processing efficiency.
# ✅ **Optimized Storage**: Saves the stitched images as **JPEG (50% quality)** for better memory management.
# ✅ **Automated Processing**: Loops through all tile folders and **recreates stitched images** automatically.
#
# This is especially useful for **machine learning preprocessing, pathology research, and efficient visualization** of large histology datasets. 🚀🔬

# %%
import os
import re
import cv2
import numpy as np

# Define input and output folders
tiles_root_folder = r"D:\MLPR DATASET\converted_tiles"
stitch_output_folder = r"D:\MLPR DATASET\Converted_Images"
os.makedirs(stitch_output_folder, exist_ok=True)

def extract_coords(filename):
    """
    Extract (x, y) coordinates from a filename formatted as 'tile_x_y.jpg'.
    """
    match = re.search(r"tile_(\d+)_(\d+)\.jpg", filename)
    if match:
        return int(match.group(1)), int(match.group(2))
    return None

def stitch_and_compress(tiles_folder, output_filename, scale=10):
    """
    Reads all JPEG tiles in a folder, downsizes each tile by the given scale,
    stitches them into one image based on their coordinates, and saves the final
    compressed image.
    """
    # List all .jpg files in the folder
    tiles = [f for f in os.listdir(tiles_folder) if f.endswith(".jpg")]
    tile_dict = {}
    tile_size = None

    # Build a dictionary mapping coordinates to tile filenames, and determine tile size
    for tile in tiles:
        coord = extract_coords(tile)
        if coord:
            tile_dict[coord] = tile
            if tile_size is None:
                img = cv2.imread(os.path.join(tiles_folder, tile))
                if img is not None:
                    tile_size = img.shape[:2]  # (height, width)
    
    if tile_size is None:
        print(f"No valid tiles found in {tiles_folder}")
        return

    # Get unique x and y coordinate values from tile filenames
    x_coords = sorted({coord[0] for coord in tile_dict.keys()})
    y_coords = sorted({coord[1] for coord in tile_dict.keys()})

    # Compute downscaled tile dimensions
    tile_height, tile_width = tile_size
    small_tile_height = tile_height // scale
    small_tile_width = tile_width // scale

    # Compute final stitched image size at downscaled resolution
    stitched_width_small = len(x_coords) * small_tile_width
    stitched_height_small = len(y_coords) * small_tile_height

    # Create a blank canvas for the downscaled stitched image
    small_grid = np.zeros((stitched_height_small, stitched_width_small, 3), dtype=np.uint8)

    # Place each tile in its correct position on the downscaled canvas
    for x in x_coords:
        for y in y_coords:
            tile_name = tile_dict.get((x, y))
            if tile_name:
                img = cv2.imread(os.path.join(tiles_folder, tile_name))
                if img is None:
                    scaled_tile = np.zeros((small_tile_height, small_tile_width, 3), dtype=np.uint8)
                else:
                    # Downscale the tile
                    scaled_tile = cv2.resize(img, (small_tile_width, small_tile_height), interpolation=cv2.INTER_AREA)
            else:
                scaled_tile = np.zeros((small_tile_height, small_tile_width, 3), dtype=np.uint8)
            # Determine the position indices in the downscaled grid
            x_idx = x_coords.index(x)
            y_idx = y_coords.index(y)
            small_grid[y_idx * small_tile_height:(y_idx + 1) * small_tile_height,
                       x_idx * small_tile_width:(x_idx + 1) * small_tile_width] = scaled_tile

    # Save the compressed stitched image (JPEG quality 50)
    cv2.imwrite(output_filename, small_grid, [cv2.IMWRITE_JPEG_QUALITY, 50])
    print(f"Compressed stitched image saved at: {output_filename}")

    # Optionally, display the compressed image (press any key to close)
    cv2.imshow("Stitched Image", small_grid)
    cv2.waitKey(0)
    cv2.destroyAllWindows()

# Process each folder in the root folder and save the resulting stitched image in the output folder
for folder_name in os.listdir(tiles_root_folder):
    folder_path = os.path.join(tiles_root_folder, folder_name)
    if os.path.isdir(folder_path):
        output_filename = os.path.join(stitch_output_folder, f"{folder_name}_stitched_compressed.jpg")
        print(f"Processing folder: {folder_name}")
        stitch_and_compress(folder_path, output_filename, scale=10)
# Out:
# Processing folder: 7316UP-109
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-109_stitched_compressed.jpg
# Processing folder: 7316UP-1108
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1108_stitched_compressed.jpg
# Processing folder: 7316UP-1110
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1110_stitched_compressed.jpg
# Processing folder: 7316UP-1135
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1135_stitched_compressed.jpg
# Processing folder: 7316UP-1206
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1206_stitched_compressed.jpg
# Processing folder: 7316UP-1220
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1220_stitched_compressed.jpg
# Processing folder: 7316UP-1273
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1273_stitched_compressed.jpg
# Processing folder: 7316UP-1282
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1282_stitched_compressed.jpg
# Processing folder: 7316UP-1302
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1302_stitched_compressed.jpg
# Processing folder: 7316UP-1352
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1352_stitched_compressed.jpg
# Processing folder: 7316UP-1405
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1405_stitched_compressed.jpg
# Processing folder: 7316UP-1534
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1534_stitched_compressed.jpg
# Processing folder: 7316UP-1581
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1581_stitched_compressed.jpg
# Processing folder: 7316UP-160
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-160_stitched_compressed.jpg
# Processing folder: 7316UP-1614
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1614_stitched_compressed.jpg
# Processing folder: 7316UP-1640
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1640_stitched_compressed.jpg
# Processing folder: 7316UP-1766
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1766_stitched_compressed.jpg
# Processing folder: 7316UP-181
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-181_stitched_compressed.jpg
# Processing folder: 7316UP-1843
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1843_stitched_compressed.jpg
# Processing folder: 7316UP-1848
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1848_stitched_compressed.jpg
# Processing folder: 7316UP-1883
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-1883_stitched_compressed.jpg
# Processing folder: 7316UP-19
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-19_stitched_compressed.jpg
# Processing folder: 7316UP-2058
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2058_stitched_compressed.jpg
# Processing folder: 7316UP-2100
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2100_stitched_compressed.jpg
# Processing folder: 7316UP-2110
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2110_stitched_compressed.jpg
# Processing folder: 7316UP-213
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-213_stitched_compressed.jpg
# Processing folder: 7316UP-2165
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2165_stitched_compressed.jpg
# Processing folder: 7316UP-219
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-219_stitched_compressed.jpg
# Processing folder: 7316UP-2310
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2310_stitched_compressed.jpg
# Processing folder: 7316UP-2333
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2333_stitched_compressed.jpg
# Processing folder: 7316UP-243
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-243_stitched_compressed.jpg
# Processing folder: 7316UP-2527
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2527_stitched_compressed.jpg
# Processing folder: 7316UP-2726
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2726_stitched_compressed.jpg
# Processing folder: 7316UP-2837
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2837_stitched_compressed.jpg
# Processing folder: 7316UP-2843
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2843_stitched_compressed.jpg
# Processing folder: 7316UP-287
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-287_stitched_compressed.jpg
# Processing folder: 7316UP-2923
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-2923_stitched_compressed.jpg
# Processing folder: 7316UP-293
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-293_stitched_compressed.jpg
# Processing folder: 7316UP-302
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-302_stitched_compressed.jpg
# Processing folder: 7316UP-3213
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-3213_stitched_compressed.jpg
# Processing folder: 7316UP-3301
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-3301_stitched_compressed.jpg
# Processing folder: 7316UP-334
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-334_stitched_compressed.jpg
# Processing folder: 7316UP-349
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-349_stitched_compressed.jpg
# Processing folder: 7316UP-35
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-35_stitched_compressed.jpg
# Processing folder: 7316UP-361
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-361_stitched_compressed.jpg
# Processing folder: 7316UP-3639
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-3639_stitched_compressed.jpg
# Processing folder: 7316UP-3741
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-3741_stitched_compressed.jpg
# Processing folder: 7316UP-386
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-386_stitched_compressed.jpg
# Processing folder: 7316UP-393
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-393_stitched_compressed.jpg
# Processing folder: 7316UP-421
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-421_stitched_compressed.jpg
# Processing folder: 7316UP-426
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-426_stitched_compressed.jpg
# Processing folder: 7316UP-435
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-435_stitched_compressed.jpg
# Processing folder: 7316UP-483
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-483_stitched_compressed.jpg
# Processing folder: 7316UP-485
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-485_stitched_compressed.jpg
# Processing folder: 7316UP-498
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-498_stitched_compressed.jpg
# Processing folder: 7316UP-504
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-504_stitched_compressed.jpg
# Processing folder: 7316UP-534
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-534_stitched_compressed.jpg
# Processing folder: 7316UP-547
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-547_stitched_compressed.jpg
# Processing folder: 7316UP-553
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-553_stitched_compressed.jpg
# Processing folder: 7316UP-574
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-574_stitched_compressed.jpg
# Processing folder: 7316UP-587
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-587_stitched_compressed.jpg
# Processing folder: 7316UP-603
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-603_stitched_compressed.jpg
# Processing folder: 7316UP-613
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-613_stitched_compressed.jpg
# Processing folder: 7316UP-662
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-662_stitched_compressed.jpg
# Processing folder: 7316UP-743
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-743_stitched_compressed.jpg
# Processing folder: 7316UP-8
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-8_stitched_compressed.jpg
# Processing folder: 7316UP-895
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-895_stitched_compressed.jpg
# Processing folder: 7316UP-961
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-961_stitched_compressed.jpg
# Processing folder: 7316UP-979
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-979_stitched_compressed.jpg
# Processing folder: 7316UP-984
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-984_stitched_compressed.jpg
# Processing folder: 7316UP-99
# Compressed stitched image saved at: D:\MLPR DATASET\Converted_Images\7316UP-99_stitched_compressed.jpg
