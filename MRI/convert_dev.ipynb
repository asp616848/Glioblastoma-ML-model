# %%
pip install nibabel pydicom
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/3.3 MB ? eta -:--:--
#    --- ------------------------------------ 0.3/3.3 MB ? eta -:--:--
#    ------ --------------------------------- 0.5/3.3 MB 1.5 MB/s eta 0:00:02
#    ------------ --------------------------- 1.0/3.3 MB 1.6 MB/s eta 0:00:02
#    ------------------- -------------------- 1.6/3.3 MB 1.8 MB/s eta 0:00:01
#    ---------------------------------------- 3.3/3.3 MB 3.5 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/2.4 MB ? eta -:--:--
#    ---------------------------------------- 2.4/2.4 MB 13.6 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.2 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import os
# import subprocess

# # Paths to the two DICOM folders
# dicom_folders = [
#     r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693",
#     r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-41468\8.000000-ep2ddiffMDDWIPAT-81031"
# ]

# # Path to dcm2niix.exe
# dcm2niix_path = r"D:\Z\dcm2niix\dcm2niix.exe"

# # Output folder for NIfTI files
# output_folder = r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI"

# # Create the output folder if it doesn't exist
# os.makedirs(output_folder, exist_ok=True)

# # Convert each DICOM folder to NIfTI
# for dicom_folder in dicom_folders:
#     print(f"Converting DICOM files in: {dicom_folder}")
    
#     # Run dcm2niix with full path
#     subprocess.run([dcm2niix_path, "-o", output_folder, "-z", "y", dicom_folder])

# print("Conversion complete!")
# Out:
# Converting DICOM files in: D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693
# Converting DICOM files in: D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-41468\8.000000-ep2ddiffMDDWIPAT-81031
# Conversion complete!

# %% [markdown]
# ## With JSON

# %%
import os
import subprocess
import glob

# Paths to the two DICOM folders
dicom_folders = {
    "BRAINROUTINE-33106": r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693",
    "BRAINROUTINE-41468": r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-41468\8.000000-ep2ddiffMDDWIPAT-81031"
}

# Path to dcm2niix.exe
dcm2niix_path = r"D:\Z\dcm2niix\dcm2niix.exe"

# Base output folder for NIfTI files
base_output_folder = r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI"
os.makedirs(base_output_folder, exist_ok=True)  # Ensure base output folder exists

# Convert each DICOM folder separately
for folder_name, dicom_folder in dicom_folders.items():
    output_folder = os.path.join(base_output_folder, folder_name)  # Create a subfolder for each DICOM folder
    os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists
    
    dicom_files = glob.glob(os.path.join(dicom_folder, "*"))  # Get all DICOM files
    
    for dicom_file in dicom_files:
        if os.path.isfile(dicom_file):  # Ensure it's a file
            filename = os.path.basename(dicom_file).split('.')[0]  # Extract filename
            output_name = os.path.join(output_folder, filename)  # Output filename

            print(f"Converting: {dicom_file} → {output_folder}")
            
            # Run dcm2niix for each file separately
            subprocess.run([dcm2niix_path, "-o", output_folder, "-f", filename, "-z", "y", dicom_file])

print("Conversion complete!")

# %% [markdown]
# ## Without JSON

# %%
# import os
# import subprocess
# import glob

# # Paths to the two DICOM folders
# dicom_folders = {
#     "BRAINROUTINE-33106": r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693",
#     "BRAINROUTINE-41468": r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-41468\8.000000-ep2ddiffMDDWIPAT-81031"
# }

# # Path to dcm2niix.exe
# dcm2niix_path = r"D:\Z\dcm2niix\dcm2niix.exe"

# # Base output folder for NIfTI files
# base_output_folder = r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI"
# os.makedirs(base_output_folder, exist_ok=True)  # Ensure base output folder exists

# # Convert each DICOM folder separately
# for folder_name, dicom_folder in dicom_folders.items():
#     output_folder = os.path.join(base_output_folder, folder_name)  # Create a subfolder for each DICOM folder
#     os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists
    
#     dicom_files = glob.glob(os.path.join(dicom_folder, "*"))  # Get all DICOM files
    
#     for dicom_file in dicom_files:
#         if os.path.isfile(dicom_file):  # Ensure it's a file
#             filename = os.path.basename(dicom_file).split('.')[0]  # Extract filename
#             output_name = os.path.join(output_folder, filename)  # Output filename

#             print(f"Converting: {dicom_file} → {output_folder}")
            
#             # Run dcm2niix for each file separately (WITHOUT JSON using -b n)
#             subprocess.run([dcm2niix_path, "-o", output_folder, "-f", filename, "-z", "y", "-b", "n", dicom_file])

# print("Conversion complete!")

# %% [markdown]
# ## No JSON no ZIPPING

# %%
import os
import subprocess
import glob

# Paths to the two DICOM folders
dicom_folders = {
    "BRAINROUTINE-33106": r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693",
    "BRAINROUTINE-41468": r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-41468\8.000000-ep2ddiffMDDWIPAT-81031"
}

# Path to dcm2niix.exe
dcm2niix_path = r"D:\Z\dcm2niix\dcm2niix.exe"

# Base output folder for NIfTI files
base_output_folder = r"D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI"
os.makedirs(base_output_folder, exist_ok=True)  # Ensure base output folder exists

# Convert each DICOM folder separately
for folder_name, dicom_folder in dicom_folders.items():
    output_folder = os.path.join(base_output_folder, folder_name)  # Create a subfolder for each DICOM folder
    os.makedirs(output_folder, exist_ok=True)  # Ensure output folder exists
    
    dicom_files = glob.glob(os.path.join(dicom_folder, "*"))  # Get all DICOM files
    
    for dicom_file in dicom_files:
        if os.path.isfile(dicom_file):  # Ensure it's a file
            filename = os.path.basename(dicom_file).split('.')[0]  # Extract filename
            output_name = os.path.join(output_folder, filename)  # Output filename

            print(f"Converting: {dicom_file} → {output_folder}")
            
            # Run dcm2niix for each file separately (WITHOUT JSON and WITHOUT COMPRESSION)
            subprocess.run([dcm2niix_path, "-o", output_folder, "-f", filename, "-z", "n", "-b", "n", dicom_file])

print("Conversion complete!")
# Out:
# Converting: D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693\1-01.dcm → D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI\BRAINROUTINE-33106
# Converting: D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693\1-02.dcm → D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI\BRAINROUTINE-33106
# Converting: D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693\1-03.dcm → D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI\BRAINROUTINE-33106
# Converting: D:\SEM_4\MLPR LAB (SEM-4)\Proj\02-06-2002-NA-BRAINROUTINE-33106 & 41468\02-06-2002-NA-BRAINROUTINE-33106\2.000000-t2Flairaxial ProcessedCaPTk-17693\1-04.dcm → D:\SEM_4\MLPR LAB (SEM-4)\Proj\Converted_NIfTI\BRAINROUTINE-33106
# ...
